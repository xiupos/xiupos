# %% [markdown]
# ---
# title: "Jupyter Notebook テスト"
# pubDate: 2025-11-25T22:30:00+09:00
# math: true
# lang: ja
# draft: true
# slug: computer/jupyter-test
# ---

# %% [markdown]
# Jupyter Notebook で直接記事を書くテスト.

# %% [markdown]
# ## Hello, world!

# %%
println("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## グラフのテスト
#
# 正弦波
# $$
# y = \sin x \quad (-π ≤ x ≤ π)
# $$
# を描画してみる.

# %%
using Plots

x = range(-π, π, 64)
y = sin.(x)

plot(x, y)
